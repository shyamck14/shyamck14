# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamck14/shyamck14/blob/master/FruitShop_Billing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Flow of our Project:**
# - Accept the Product name (purchased by consumer)
# - quantity of the purchased product
# - accept consumer membership ( Gold 20%, Silver 10%, Bronze 5% )
# - calculate final bill amount
#
# ---------------------------------
# # **simple function creation**
#
# enterProducts()
# - This will accept two things from user
# 1. name of the product
# 2. quantity of the product
#
# NOTE:
#   - we need these two attributes , they are directly connected to each other
#   - we need a data structure that stores both "name" and "quantity"
#
#   - we accept these two and store in a **dictionary**
#   - where Product name will be **key** and
#   - "**quantity**" will be its **value**
#   - repeat the process untill entering all product details
#   - no of products is not fixed , unsure of how many times this process needs to repeat so when no of iterations is not fixed we use **while loop **
#
# CODE EXPLANATION
#
# # **PART ONE**
#
# def enterProducts():
#   buyingData ={}
#   enterDetails = True
#   while enterDetails:
#     details = input('press A to add product and Q to quit:')
#
# - enterProducts() is name of function , it does not take any parameters.
# - we need to store product name and quantity in dictionary so we define a dictionary that will be initially empty
# - next define looping variable 'enterDetails' this will set to True initaially
# - we need loop to atleast run once and prompt the user to input data
# -  This is the common way of using **while loop**
#
# start of the loop
# - created a flag variable (enterDetails), gave default value (True)
#
# inside the loop block
# - depending on requirement we change value to continue loop or not
# NOTE: do not forget to change the flag variable inside loop
#
# # **PART TWO ** **bold text**
#
# if details == "A":
#       product = input('Enter product:')
#       quantity = int(input('Enter quantity:'))
#       buyingData.update({product:quantity})
#     elif details == 'Q':
#         enterDetails = False
#     else:
#           print('please select a correct option')
#           return buyingData
#
# - 'A' need to accept product details , else need to break the loop thus we use concept of **conditional statements** that helps to make decision
# - compare cashier input using '==' operator ,quantity has to be numeric
# - used update() method which will add new **key value-pair** in dictionary
# -------------------------
#
# PRICE CALCULATION
#
# To calculate the total price of the shopping by consumer
#
# This price is not a final price we have membership discount next so we call it as **"subtotal amount"**
#
# **LOGIC**
#
# **simple function creation**
# - getPrice() will have two parameters ( product and quantity )
# - we need **predefined dictionary ** contains product name as key and product price as value
#
# # **CODE EXPLANATION**
#
# **PART ONE **
#
# def getPrice(product,quantity):
#   priceData = {'Biscuit':3, 'Bread':2, 'Egg':6}
#
# - getPrice(product,quantity) function accepts two parameters
# - data will come from retrun value of enterProducts() function
# - then defined dictionary and name as priceData which has product as key and product price as value
#
# NOTE
# - {} is used to define dictionary
# - in dictionary we cannot have key as a string only
#
# # **PART TWO**
#
# subtotal = priceData[product]*quantity
#   print(product + ':$' + str(priceData[product])) + 'x' + str(quantity) + '=' + str(subtotal)
#   return subtotal
#
# - we have price simply multiply it with quantity it gives subtotal
# - we need to typecast as string str() method
#
# NOTE
#
# - str() METHOD is used to convert int to string
# - dictName[key] syntax is used to fetch value from dictionary using its key
# - [product name]:[$price]x[quantity]=[subtotal]
#
# **DISCOUNT CALCULATION**
#
# - After we get subtotal amount check with consumer membership discount
# - if yes deduct the amount from subtotal
# - this will be final billing amount
# - add one more condition, discount will be given only if billing amount is greater than $25
# - we use if-else constructs and check for membership
# - Gold 20%, Silver 10%, Bronze 5%
#
# **CODE EXPLANATION**
#
# def getDiscount(billAmount, membership):
#   discount = 0
#   if billAmount >= 25:
#
# - def getDiscount(billAmount, membership) function accepts two parameters
# - we declare variable discount and initialize to zero
# - check for discount condition , bill greater than $25, then only cal discount
#
# **PART TWO **
#
# if billAmount >= 25:
#     if membership == 'Gold':
#       billAmount = billAmount*0.80
#       discount = 20
#     elif membership == 'Silver':
#       billAmount = billAmount*0.90
#       discount = 10
#     elif membership == 'Bronze':
#       billAmount = billAmount*0.95
#       discount = 5
#     print(str(discount) + '% off for ' + membership + ' membership on total amount: $' + str(billAmount))
#
#   - if bill greater than $25 we have nested if else ,check for membership type
#
#
# **PART THREE **
#
# else:
#       print('No discount on less than $25')
#       return billAmount
#
# - If bill is less than $25, return the bill
#
#
# # **MAKING BILL **
#
# CODE EXPLANATION
#
# def makeBill(buyingData, membership):
#
# - Two parameters, customer products purchased and membership
#
# billAmount = 0
#
# - declared and initialized the variable billAmount that holds subtotal
#
# for key, value in buyingData.items():
#     billAmount += getPrice(key,value)
#
# - getPrice() will return subtotal, loop used
# - iterate over dictionary buyingData and fetch key and value using item() method
#
# # **NOTE: **
#
# - a += b expression is nothing but another way of a = a=b
#
# billAmount = getDiscount(billAmount, membership)
# - returns the final bill amount
#
#  print('The discounted amount is $'+ str (billAmount))
#  - our makeBill() funtion

# %%
def enterProducts():
    buyingData = {}
    enterDetails = True
    while enterDetails:
        details = input("Press A to add product and Q to quit: ")
        if details == "A":
            product = input("Enter product: ")
            quantity = int(input("Enter quantity: "))
            buyingData.update({product: quantity})
        elif details == "Q":
            enterDetails = False
        else:
            print("Please select a correct option")
    return buyingData


def getPrice(product, quantity):
    priceData = {
        'Apple': 3,
        'Banana': 5,
        'Grape': 1,
        'Watermelon': 3,
        'Amla': 2,
        'Strawberry': 2,
        'Orange': 3,
        'Kiwi': 3
    }
    subtotal = priceData[product] * quantity
    print(product + ':$' +
          str(priceData[product]) + 'x' + str(quantity) + '=' + str(subtotal))
    return subtotal


def getDiscount(billAmount, membership):
    discount = 0
    if billAmount >= 25:
        if membership == 'Gold':
            billAmount = billAmount * 0.80
            discount = 20
        elif membership == 'Silver':
            billAmount = billAmount*0.90
            discount = 10
        elif membership == 'Bronze':
            billAmount = billAmount*0.95
            discount = 5
        print(str(discount) + "% off for " + membership +
              " " + "membership on  total amount: $" + str(billAmount))
    else:
        print("No discount on amount less than $25")
    return billAmount


def makeBill(buyingData, membership):
    billAmount = 0
    for key, value in buyingData.items():
        billAmount += getPrice(key, value)
    billAmount = getDiscount(billAmount, membership)
    print("The discounted amount is $" + str(billAmount))


buyingData = enterProducts()
membership = input("Enter customer membership: ")
makeBill(buyingData, membership)
# Out:
# Press A to add product and Q to quit: A
# Enter product: Kiwi
# Enter quantity: 20
# Press A to add product and Q to quit: Q
# Enter customer membership: Gold
# Kiwi:$3x20=60
# 20% off for Gold membership on  total amount: $48.0
# The discounted amount is $48.0
